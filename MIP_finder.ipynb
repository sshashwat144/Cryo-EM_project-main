# %%
import mrcfile 
import matplotlib.pyplot as plt
import numpy as np

with mrcfile.open("miptest1.mrc") as mrc:
    c= mrc.data
print(c.shape)
plt.imshow(c[0], cmap = 'gray')
c.max()
# Out:
# (1, 2864, 4032)
# 6.2955494

# %%
c[0]
# Out:
# array([[1.1407555 , 1.4666253 , 1.2818177 , ..., 1.8958298 , 1.5712895 ,
#         1.2417314 ],
#        [0.89556605, 1.6249884 , 1.3056488 , ..., 1.3644887 , 1.2707324 ,
#         1.3050325 ],
#        [1.6039069 , 1.0581183 , 1.3482738 , ..., 1.5915042 , 1.4359683 ,
#         1.562298  ],
#        ...,
#        [1.4481634 , 1.1713027 , 1.0392728 , ..., 1.531612  , 1.3380988 ,
#         1.2865878 ],
#        [1.4646561 , 1.2480173 , 1.4502038 , ..., 1.1867931 , 1.3045759 ,
#         1.2953708 ],
#        [1.5101825 , 1.1983278 , 1.3047016 , ..., 1.2265385 , 0.9548982 ,
#         1.6278255 ]], dtype=float32)

# %%
import mrcfile 
import matplotlib.pyplot as plt

with mrcfile.open("To_copy_1/Reconstructed 15000 components ribosome.mrc") as mrc:
    b= mrc.data
print(c.shape)
plt.imshow(b, cmap='gray')
c.max()
# Out:
# (1, 128, 128)
# 0.0008074959

# %%
import mrcfile 
import matplotlib.pyplot as plt

with mrcfile.open("To_copy/Reconstructed 1000 components ribosome.mrc") as mrc:
    b= mrc.data
print(c.shape)
plt.imshow(b, cmap='gray')
c.max()
# Out:
# (1, 128, 128)
# 0.0008074959

# %%
import mrcfile 
import matplotlib.pyplot as plt

with mrcfile.open("all1.mrc") as mrc:
    b= mrc.data
print(b.shape)
plt.imshow(b[0])
b.max()
# Out:
# (92, 2864, 4032)
# 11.221656

# %%
import mrcfile 
import matplotlib.pyplot as plt

with mrcfile.open("/home/useradmin/Project_cisTEM/Reconstructed_15000_components_ribosome.mrc") as mrc:
    b= mrc.data
print(b.shape)
plt.imshow(b[1])
# Out:
# (92, 128, 128)

# %%
import mrcfile 
import matplotlib.pyplot as plt

with mrcfile.open("/home/useradmin/Project_cisTEM/all_peaks.mrc") as mrc:
    b= mrc.data
print(b.shape)
plt.imshow(b[1])
# Out:
# (92, 128, 128)

# %%
vals = []
import numpy as np
for i in range(92):
    vals.append(np.max(b[i]))
    if(np.max(b[i]) > 7.43):
        print(np.max(b[i]))
        
        
vals
# Out:
# 11.221656
# [11.221656,
#  5.3972874,
#  5.2405725,
#  5.4872766,
#  5.442951,
#  5.0867968,
#  5.1614366,
#  5.4541206,
#  5.2636867,
#  4.987357,
#  5.081624,
#  6.0375805,
#  5.318049,
#  5.4201493,
#  5.2291284,
#  5.4687624,
#  5.365422,
#  5.4187546,
#  5.597881,
#  5.264289,
#  5.19771,
#  5.1245885,
#  5.139837,
#  5.070295,
#  5.3734837,
#  5.2267904,
#  5.7179294,
#  5.0787067,
#  5.1859374,
#  5.278207,
#  5.316015,
#  5.4033303,
#  5.185725,
#  5.330159,
#  5.4527516,
#  5.361599,
#  5.397667,
#  5.2998877,
#  5.5149493,
#  5.1209564,
#  5.434417,
#  5.3632555,
#  5.000124,
#  5.629818,
#  5.4596744,
#  5.155005,
#  5.402418,
#  5.4316297,
#  5.165059,
#  5.070556,
#  5.504638,
#  5.5720277,
#  5.4826293,
#  5.3862576,
#  5.5405636,
#  5.255225,
#  5.96501,
#  5.830319,
#  6.0427723,
#  5.249652,
#  5.574041,
#  5.438027,
#  5.5749593,
#  5.6667275,
#  5.4238667,
#  5.18245,
#  5.158704,
#  5.9490623,
#  5.406631,
#  5.3861914,
#  5.0087743,
#  5.441665,
#  5.348033,
# ...

# %%
from skimage.metrics import structural_similarity as ssim
import numpy as np
data_range = (np.amax(c) - np.amin(c))
ssim(c[0], b, data_range = data_range)
# Out:
# 0.39831925224988884

# %%
import mrcfile 
import matplotlib.pyplot as plt

with mrcfile.open("zmip.mrc") as mrc:
    c= mrc.data
c = c[0]
print(c.shape)
plt.imshow(c)
c.max()
# Out:
# (2916, 4096)
# 12.120094

# %%
import mrcfile 
import matplotlib.pyplot as plt

with mrcfile.open("Testing/test/outputs/mip.mrc") as mrc:
    c= mrc.data
c = c[0]
print(c.shape)
plt.imshow(c)
c.max()
# Out:
# (2864, 4032)
# 12.287109

# %%
check = []
for i in range(c.shape[0]):
    d = c[i]
    for j in range(d.shape[0]):
        if d[j] > 7.43:
            check.append(c[i][j])

# %%
len(check)
# Out:
# 404

# %%
check
# Out:
# [8.10791,
#  8.114502,
#  7.949707,
#  8.068359,
#  8.068359,
#  11.766357,
#  9.663574,
#  8.991211,
#  7.6135254,
#  7.9365234,
#  10.388672,
#  7.5805664,
#  7.7058105,
#  7.620117,
#  9.301025,
#  8.351807,
#  7.6794434,
#  8.964844,
#  7.817871,
#  7.468506,
#  7.7453613,
#  8.266113,
#  7.4816895,
#  7.9299316,
#  8.285889,
#  8.641846,
#  7.817871,
#  8.200195,
#  9.004395,
#  8.819824,
#  7.587158,
#  7.8046875,
#  7.66626,
#  8.009033,
#  7.751953,
#  8.846191,
#  8.2265625,
#  7.989258,
#  7.85083,
#  12.287109,
#  7.6464844,
#  7.5080566,
#  7.4421387,
#  7.6398926,
#  7.5476074,
#  7.52124,
#  7.461914,
#  7.6464844,
#  7.4421387,
#  7.916748,
#  7.758545,
#  7.7453613,
#  7.527832,
#  7.494873,
#  8.1936035,
#  7.4816895,
#  7.6992188,
#  7.5080566,
#  7.5080566,
#  7.6464844,
#  7.5080566,
#  7.4816895,
#  7.501465,
#  7.435547,
#  7.7651367,
#  8.2595215,
#  7.527832,
#  7.4750977,
#  7.4882812,
#  7.5080566,
#  7.6069336,
#  7.758545,
#  7.600342,
#  7.4882812,
# ...

# %%
import mrcfile 
import numpy as np
with mrcfile.open("00040_3_0.mrc") as mrc:
    b= mrc.data
b = b[0]
new  = np.reshape(b, (4032, 2864))
print(b.shape)
print(new.shape)
# Out:
# (2864, 4032)
# (4032, 2864)

# %%
a[0][4000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a[0][4000]
#
# IndexError: index 4000 is out of bounds for axis 0 with size 2864

# %%
import matplotlib.pyplot as plt
plt.imshow(a[0])

# %%
a[0][1951][3735] * np.sqrt(4032 * 2864)
# Out:
# -0.5276872028481903
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
c[1951][3735]
# Out:
# 11.819092

# %%
data  =a[0] * np.sqrt(4032 * 2864)
# Create a histogram
hist, bin_edges = np.histogram(data, bins=30, density=True)
# Plot the histogram and the fitted Gaussian
plt.hist(data, bins=30, density=True, alpha=0.5, label='Histogram')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 5
#       3 hist, bin_edges = np.histogram(data, bins=30, density=True)
#       4 # Plot the histogram and the fitted Gaussian
# ----> 5 plt.hist(data, bins=30, density=True, alpha=0.5, label='Histogram')
#
# File ~/anaconda3/envs/Cryo-EM_project/lib/python3.11/site-packages/matplotlib/pyplot.py:3236, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3211 @_copy_docstring_and_deprecators(Axes.hist)
#    3212 def hist(
#    3213     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3234     BarContainer | Polygon | list[BarContainer | Polygon],
#    3235 ]:
# -> 3236     return gca().hist(
#    3237         x,
#    3238         bins=bins,
#    3239         range=range,
#    3240         density=density,
# ...

# %%
a[0][422][2449] * 4032 * 2864
# Out:
# 19396.573410630226

# %%
data.max()
# Out:
# 5.707925

# %%
import mrcfile
import numpy as np
with mrcfile.open("Mips/14000_components.mrc") as mrc:
    data= mrc.data

mrc.close()
data = data[0]
data = data  * np.sqrt(4032 * 2864)

# %%
import pandas as pd
df = pd.DataFrame(data)



l = df.max()
g = l.idxmax()
g
# Out:
# 3767

# %%
q = df.get(3767
            )
q.max()
# Out:
# 11.464375495910645

# %%
q.idxmax()
# Out:
# 1977

# %%
df[1940:1960][]

# %%
c[487][3137]
# Out:
# 12.168457

# %%
data[1977][3767]
# Out:
# 11.180332

# %%
type(a)
# Out:
# numpy.ndarray
