# %%
import mrcfile
import numpy as np
with mrcfile.open("Mips/15000_components.mrc") as mrc:
    y= mrc.data
    y = y[0]

mrc.close()

print(y[1977][3767] * np.sqrt(4032 * 2864))
import matplotlib.pyplot as plt
plt.imshow(y)
# Out:
# 11.464374839424325

# %%
check = []
z = y * np.sqrt(4032 * 2864)
print(z.shape)
z = z[0]
for i in range(z.shape[0]):
    d = z[i]
    for j in range(d.shape[0]):
        if d[j] > 6:
            check.append(z[i][j])
len(check)
# Out:
# (1, 2916, 4096)
# 2

# %%
import mrcfile
import numpy as np
with mrcfile.open("To_copy_2/Reconstructed 800 components ribosome.mrc") as mrc:
    y= mrc.data

mrc.close()
print(np.max(y) * np.sqrt(4032 * 2864))
import matplotlib.pyplot as plt
plt.imshow(y)
# Out:
# 3.7509133351514805
